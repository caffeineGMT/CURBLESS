# %% [markdown]
# # Brief:
# 1.understand global and local mobility of bird scotters
#
# 2.the combination of walking and biking
#
# The popularity of bird is definitely not a coincident in LA. American city like LA is so heavily relied on private vehicles. The available transportation infrastracture for the pulic is much more poor. Lack of dock for shared bikes. Lack of bicycle lanes for shared bikes. But scooter is the combination of walking and biking. reflected on the usage pattern. reflected on the utilization of sidewalks and bicyle lanes.
#
# 3.understand the ridability
#
# 4.understand the dockability
#
# 5.understand the using patern.

# %% [markdown]
# # Overall procedure
# geographic data for point of interest
#
# collect birds data
#
# cron job set up
#
# collect landuse data
#
# machine learning
#
# visualization

# %% [markdown]
# # Future
# 1.research on driverless car:
# ripple effect diminish
# simulation
# LA
#
# 2.uber helicopter
# LA

# %% [markdown]
# # Gather geography-related data

# %%
#gather shapes of area
import geopandas as gpd
fp='Downloads/la-county-neighborhoods-current/l.a. county neighborhood (current).shp'
la_neighbs=gpd.read_file(fp)
print('L.A Count GIS dataset type :{}'.format(type(la_neighbs)))
la_neighbs.head(10)
# Out:
# L.A Count GIS dataset type :<class 'geopandas.geodataframe.GeoDataFrame'>
#               slug                                  set  \
# 0            acton  L.A. County Neighborhoods (Current)
# 1  adams-normandie  L.A. County Neighborhoods (Current)
# 2     agoura-hills  L.A. County Neighborhoods (Current)
# 3       agua-dulce  L.A. County Neighborhoods (Current)
# 4         alhambra  L.A. County Neighborhoods (Current)
# 5     alondra-park  L.A. County Neighborhoods (Current)
# 6         altadena  L.A. County Neighborhoods (Current)
# 7    angeles-crest  L.A. County Neighborhoods (Current)
# 8          arcadia  L.A. County Neighborhoods (Current)
# 9           arleta  L.A. County Neighborhoods (Current)
#
#                                  kind       external_i             name  \
# 0  L.A. County Neighborhood (Current)            acton            Acton
# 1  L.A. County Neighborhood (Current)  adams-normandie  Adams-Normandie
# ...

# %%
#gather shapes of area
sidewalk_fp='Downloads/Sidewalks/Sidewalks.shp'
sidewalk=gpd.read_file(sidewalk_fp)
sidewalk.head()
# Out:
#    OBJECTID  SIDEWALK_I  ASSETID FEATURETYP         PIND NOTES  \
# 0      3001     1030022  3727454   Sidewalk  213B113-320  None
# 1      3002     1030023  3727455   Sidewalk  213B113-320  None
# 2      3003     1030024  3727456   Sidewalk  213B113-320  None
# 3      3004     1030025  3727457   Sidewalk  213B113-320  None
# 4      3005     1030026  3727458   Sidewalk  216B117-139  None
#
#                     CRTN_DT                LST_MODF_D   Shape__Are  \
# 0  2017-01-10T22:49:14.000Z  2017-01-27T19:37:32.000Z   117.249023
# 1  2017-01-10T23:17:16.000Z  2017-01-27T19:37:32.000Z   961.720703
# 2  2017-01-10T23:17:16.000Z  2017-01-27T19:37:32.000Z   648.385742
# 3  2017-01-10T23:17:16.000Z  2017-01-27T19:37:32.000Z  1641.531250
# 4  2017-01-11T01:00:07.000Z  2017-01-11T01:00:43.000Z   799.420898
#
#    Shape__Len                                           geometry
# 0   44.614741  POLYGON ((-118.569492026914 34.2802160005296, ...
# ...

# %% [markdown]
# # Gather bird scooter data

# %%
import requests
import uuid
import json
import pandas as pd
from shapely.geometry import Point

# %%
def get_auth_token(guid):
    url = 'https://api.birdapp.com/user/login'
    headers = {
        'User-Agent': 'Bird/4.41.0 (co.bird.Ride; build:37; iOS 12.3.1) Alamofire/4.41.0',
        'Device-id': guid,
        'Platform':'ios',
        'App-Version': '4.41.0',
        'Content-Type':'application/json',
    }
    payload={
        'email':'{}@example.com'.format(guid)
    }
    
    r=requests.post(url=url,data=json.dumps(payload),headers=headers)
    token=r.json().get('token')
    
    
    return token

# %%
guid=str(uuid.uuid1())
token=get_auth_token(guid)
assert token is not None
token
# Out:
# 'eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJBVVRIIiwidXNlcl9pZCI6IjA2MmUyMzc4LTMyYTMtNDAyZi1hZWQ5LTIxZmFkMjAxNThiOCIsImRldmljZV9pZCI6ImRkZDQ3MTYwLWNmOGUtMTFlOS05MzY4LWFjZGU0ODAwMTEyMiIsImV4cCI6MTU5OTE5MDgxM30.P3wPFN8zKbqb4O0C6ol0I-9KY-QSkbmEg5Ta-Hynd34'

# %%
def get_near_by_scooters(token,lat,long):
    url = 'https://api.birdapp.com/bird/nearby'
    params = {
        'latitude':lat,
        'longitude':long,
        'radius':5000
    }
    headers = {
        'Authorization':'Bird {}'.format(token),
        'Device-id':'{}'.format(guid),
        'App-Version':'4.41.0',
        'Location':json.dumps({
            'latitude':lat,
            'longitude':long,
            'altitude':500,
            'accuracy':100,
            'speed':-1,
            'heading':-1
        })
    }
    r = requests.get(url=url, params=params, headers=headers)
    
    scooters=r.json().get('birds')

    return scooters

# %%
def split_location(df,location_lable='location'):
    locs=df[location_lable].apply(pd.Series)
    df_new=pd.concat([df,locs],axis=1)
    df_new=df_new.drop(location_lable,axis=1)
    return df_new

# %%
test_location = (34.017855, -118.493678)
birds_test = pd.DataFrame(get_near_by_scooters(token, *test_location))
birds_test.head()
# Out:
#                                      id  \
# 0  1fce3e88-91ab-4f6b-a9fb-784751c97c56
# 1  fffa2b26-ec66-4d56-852c-aeb34a3fe98b
# 2  0331ed2c-01dd-4119-a44b-3eb6a6622e53
# 3  f98d28c5-08ca-42ae-99d0-c4aeef90089d
# 4  921b1117-4a56-4463-9270-a1824aa880dc
#
#                                             location code model  captive  \
# 0  {'latitude': 34.018695, 'longitude': -118.4941...         rf    False
# 1   {'latitude': 34.018262, 'longitude': -118.49209}         bd    False
# 2    {'latitude': 34.0164, 'longitude': -118.493144}         bd    False
# 3  {'latitude': 34.016689, 'longitude': -118.494971}         bd    False
# 4  {'latitude': 34.018208333333334, 'longitude': ...         rf    False
#
#    battery_level  estimated_range nest_id
# 0             44            10179     NaN
# 1             69             8357     NaN
# 2             51             6165     NaN
# 3            100            12193     NaN
# 4             67            15660     NaN

# %%
import pandas as pd
import json
Mel_Rose1=pd.read_csv('data/Santa_Monica_2019-09-14_17-31.csv')
Mel_Rose_loc=(34.0837, -118.3550)

# %%
import folium

# %%
LA_map=folium.Map(location=Mel_Rose_loc,zoom_start=14,tiles='OpenStreetMap', max_zoom=19)

# %%
tooltip='birds'
popup='yeah'


for index,bird in Mel_Rose1.iterrows():
    lat=bird['latitude']
    long=bird['longitude']
    folium.CircleMarker(
        location=[lat,long],
        radius=2,
        tooltip=tooltip,
        popup=popup,
        color='#3186cc',
        fill=True,
        fill_color='#3186cc'
    ).add_to(LA_map)
LA_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
